# %%
from PIL import Image
import pytesseract as tess
import os
import re
import cv2
import numpy as np
import pandas as pd
tess.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
imgs=os.listdir('D:/data/rc prediction output/registration number/')
for image in imgs:
    img = cv2.imread('D:/data/rc prediction output/registration number/'+image)
    lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl,a,b))
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    b,g,r = cv2.split(final)           # get b,g,r
    rgb_img = cv2.merge([r,g,b])     # switch it to rgb

    # Denoising
    dst = cv2.fastNlMeansDenoisingColored(final,None,10,10,7,21)
    cv2.imwrite('D:/data/rc prediction output/registration number processed/'+image,dst)
    i+=1

# %%
imgs=os.listdir('D:/data/rc prediction output/Name/')
for image in imgs:
    img = cv2.imread('D:/data/rc prediction output/Name/'+image)
    lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl,a,b))
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    b,g,r = cv2.split(final)           # get b,g,r
    rgb_img = cv2.merge([r,g,b])     # switch it to rgb

    # Denoising
    dst = cv2.fastNlMeansDenoisingColored(final,None,10,10,7,21)
    cv2.imwrite('D:/data/rc prediction output/Name processed/'+image,dst)
    i+=1

# %%
imgs=os.listdir('D:/data/rc prediction output/engine number/')
for image in imgs:
    img = cv2.imread('D:/data/rc prediction output/engine number/'+image)
    lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl,a,b))
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    b,g,r = cv2.split(final)           # get b,g,r
    rgb_img = cv2.merge([r,g,b])     # switch it to rgb

    # Denoising
    dst = cv2.fastNlMeansDenoisingColored(final,None,10,10,7,21)
    cv2.imwrite('D:/data/rc prediction output/engine number processed/'+image,dst)
    i+=1

# %%
imgs=os.listdir('D:/data/rc prediction output/chasis number/')
for image in imgs:
    img = cv2.imread('D:/data/rc prediction output/chasis number/'+image)
    lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl,a,b))
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    b,g,r = cv2.split(final)           # get b,g,r
    rgb_img = cv2.merge([r,g,b])     # switch it to rgb

    # Denoising
    dst = cv2.fastNlMeansDenoisingColored(final,None,10,10,7,21)
    cv2.imwrite('D:/data/rc prediction output/chasis number processed/'+image,dst)

# %%
imgs=os.listdir('D:/data/rc prediction output/registration date/')
for image in imgs:
    img = cv2.imread('D:/data/rc prediction output/registration date/'+image)
    lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl,a,b))
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    b,g,r = cv2.split(final)           # get b,g,r
    rgb_img = cv2.merge([r,g,b])     # switch it to rgb

    # Denoising
    dst = cv2.fastNlMeansDenoisingColored(final,None,10,10,7,21)
    cv2.imwrite('D:/data/rc prediction output/registration date processed/'+image,dst)

# %%
imgs=os.listdir('D:/data/rc prediction output/manufacturing date/')
for image in imgs:
    img = cv2.imread('D:/data/rc prediction output/manufacturing date/'+image)
    lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl,a,b))
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    b,g,r = cv2.split(final)           # get b,g,r
    rgb_img = cv2.merge([r,g,b])     # switch it to rgb

    # Denoising
    dst = cv2.fastNlMeansDenoisingColored(final,None,10,10,7,21)
    cv2.imwrite('D:/data/rc prediction output/manufacturing date processed/'+image,dst)

# %% [markdown]
# # reading the text

# %%
registration_number_list=[]
imgs=os.listdir('D:/data/rc prediction output/registration number processed/')
for img in imgs:
    image=Image.open('D:/data/rc prediction output/registration number processed/'+img)
    data=tess.image_to_string(image)
    registration_number_list.append(data)

# %%
name_list=[]
imgs=os.listdir('D:/data/rc prediction output/Name processed/')
for img in imgs:
    image=Image.open('D:/data/rc prediction output/Name processed/'+img)
    data=tess.image_to_string(image)
    name_list.append(data)

# %%
engine_list=[]
imgs=os.listdir('D:/data/rc prediction output/engine number processed/')
for img in imgs:
    image=Image.open('D:/data/rc prediction output/engine number processed/'+img)
    data=tess.image_to_string(image)
    engine_list.append(data)

# %%
chasis_list=[]
imgs=os.listdir('D:/data/rc prediction output/chasis number processed/')
for img in imgs:
    image=Image.open('D:/data/rc prediction output/chasis number processed/'+img)
    data=tess.image_to_string(image)
    chasis_list.append(data)

# %%
registration_date_list=[]
imgs=os.listdir('D:/data/rc prediction output/registration date processed/')
for img in imgs:
    image=Image.open('D:/data/rc prediction output/registration date processed/'+img)
    data=tess.image_to_string(image)
    registration_date_list.append(data)

# %%
mfg_list=[]
imgs=os.listdir('D:/data/rc prediction output/manufacturing date processed/')
for img in imgs:
    image=Image.open('D:/data/rc prediction output/manufacturing date processed/'+img)
    data=tess.image_to_string(image)
    mfg_list.append(data)

# %% [markdown]
# # Cleaning the text

# %% [markdown]
# # registration number

# %%
pattern1=r'.......\d{4}'
registration_num=[]
for x in range (len(registration_number_list)):
    number=(re.findall(pattern1,registration_number_list[x]))
    registration_num.append(number)
    #for x in range(len(registration_num)):
for x in range (len(registration_num)):
    if len(registration_num[x])==0:
        registration_num[x]=[0]
reg_num=[]
for x in range(len(registration_num)):
    reg_num.append(registration_num[x][0])        
reg_num
# Out:
# [' DL9CAC6215',
#  ' DL9CAC6215',
#  0,
#  ' DL2CAU7997',
#  ':DL2CAS1294',
#  ' DL3CBU4111',
#  0,
#  ' DL9CAC1454',
#  ' DL8CAN1006',
#  ' DLSCAE2930',
#  ' DL8CAH3172',
#  ' DL5CJ 7852',
#  ' DL5CJ 5387',
#  ' DL8CU 7889',
#  ' DL6CN 3195',
#  ' DL5CJ 4987',
#  ' DL8CP 6677',
#  ' DL9Cx 3096',
#  ': DL1CU8248',
#  'DL30-9D0144',
#  'DLS5CJ 6088',
#  ' DL2CAM0993',
#  ' DL3CAX6515',
#  ' DL3CAX6515',
#  ' DL3CAX6515',
#  ' DL2CAF6866',
#  ' DL2CAF6866',
#  ' DL3CAD3216',
#  'IRIO-M-5657',
#  0,
#  'HR42-A-4854',
#  'RLO-P- 0840',
#  '10- P- 9470',
#  ' DL9CAC6215']

# %% [markdown]
# # name

# %%
list_1=[]
for x in range(len(name_list)):
    y=name_list[x].replace('NAME',"")
    list_1.append(y)

list_2=[]
for x in range(len(list_1)):
    z=list_1[x].replace('MR.','')
    list_2.append(z)
    

pattern=r'[A-Z]+ [A-Z]+'

n=[]
for x in range(len(list_2)):
    t=re.findall(pattern,list_2[x])
    n.append(t)

    
for x in range(len(n)):
    if len(n[x])==0:
        n[x]=['Missing']

for x in range(len(n)):
    if len(n[x])>1:
        del n[x][1]
    if len(n[x])>1:
        del n[x][1]
    if len(n[x])>1:
        del n[x][1]
    if len(n[x])>1:
        del n[x][1]
    if len(n[x])>1:
        del n[x][1]
    
    
#converting nested list into single list
name=[]
for x in range(len(n)):
    name.append(n[x][0])
name
# Out:
# ['SRISHTI NAYAR',
#  'Missing',
#  'ANOOP SURESH',
#  'MANJEET SINGH',
#  'ANIK NARULA',
#  'Missing',
#  'RAKESH KUMAR',
#  'Missing',
#  'SACHIN KUMAR',
#  'KARAN K',
#  'CHANDRA BHUWAN',
#  'Missing',
#  'Missing',
#  'MAMTA GOEL',
#  'KARISHMA DHAWAN',
#  'MANJULA VERMA',
#  'SUNDER LAL',
#  'Missing',
#  'Missing',
#  'RAJNISH JAI',
#  'KAMAL BHOLA',
#  'VIKAS ENGINEERING',
#  'VIKAS ENGINEERING',
#  'VIKAS ENGINEERING',
#  'Missing',
#  'Missing',
#  'MAHABIR SINGH',
#  'ANTIRYTAV TAIN',
#  'SUBE SINGH',
#  'Missing',
#  'PAMAM KURI',
#  'MR VIMAY',
#  'Missing',
#  'Missing',
#  'Missing',
#  'SANDEEP LAKRA',
#  'DAVENDER SINGH',
#  'Missing']

# %% [markdown]
# # engine number

# %%
eng=[]
for x in range(len(engine_list)):
    #a=engine_list[x].replace('\n',"")
    eng.append(engine_list[x].replace('ENO',""))

eng_2=[]
for x in range(len(engine_list)):
    #a=engine_list[x].replace('\n',"")
    eng_2.append(eng[x].replace('CH.NO',""))
    
eng_3=[]
for x in range(len(engine_list)):
    #a=engine_list[x].replace('\n',"")
    eng_3.append(eng_2[x].replace('NO',""))

eng_4=[]
for x in range(len(engine_list)):
    #a=engine_list[x].replace('\n',"")
    eng_4.append(eng_3[x].replace('Engine No.',""))
    
eng_5=[]
for x in range(len(engine_list)):
    #a=engine_list[x].replace('\n',"")
    eng_5.append(eng_4[x].replace('NO.',""))    
    
eng_7=[]
for x in range(len(engine_list)):
    #a=engine_list[x].replace('\n',"")
    eng_7.append(eng_5[x].replace('Engine',""))    
    
    
#to remove punctuation and spaces
pattern=r'[^\W+]+'    
    
eng_8=[]
for x in range(len(engine_list)):
    eng_8.append(re.findall(pattern,eng_7[x]))

# %%
#to remove all the words with length less than 10 charecters
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break
for x in range(len(eng_8)):
    for y in range(len(eng_8[x])):
        if len(eng_8[x][y])<10:
            del eng_8[x][y]
            break

eng_8
# Out:
# [[],
#  [],
#  [],
#  [],
#  ['K12MN1262837'],
#  ['p43A1833010'],
#  [],
#  ['K10BN4298995'],
#  [],
#  ['MA3ETDE1S00159552'],
#  ['013A2368228'],
#  [],
#  [],
#  [],
#  ['K10BN7228183'],
#  ['KT2MN4034468'],
#  ['M16AN2011764'],
#  [],
#  [],
#  [],
#  ['LAAM4SS098_'],
#  ['475IDTT4KRZPBS619'],
#  ['473IDT14KRZPBS8919'],
#  ['60714EKRZwo0Ee2'],
#  ['G16BBN521579'],
#  ['G16BBN521579'],
#  [],
#  [],
#  [],
#  ['FOON1266647'],
#  ['D13A2235550'],
#  [],
#  [],
#  ['013A2899227'],
#  [],
#  [],
#  ['G4EB9M256677'],
#  ['D4FA9U817848'],
#  []]

# %%
for x in range(len(eng_8)):
    if len(eng_8[x])>1:
        del eng_8[x][0]

#imputing missing values with 'missing'
for x in range(len(eng_8)):
    if len(eng_8[x])==0:
        eng_8[x]=['Missing']

engine=[]
for x in range(len(eng_8)):
    engine.append(eng_8[x][0])

# %%
engine
# Out:
# ['Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'K12MN1262837',
#  'p43A1833010',
#  'Missing',
#  'K10BN4298995',
#  'Missing',
#  'MA3ETDE1S00159552',
#  '013A2368228',
#  'Missing',
#  'Missing',
#  'Missing',
#  'K10BN7228183',
#  'KT2MN4034468',
#  'M16AN2011764',
#  'Missing',
#  'Missing',
#  'Missing',
#  'LAAM4SS098_',
#  '475IDTT4KRZPBS619',
#  '473IDT14KRZPBS8919',
#  '60714EKRZwo0Ee2',
#  'G16BBN521579',
#  'G16BBN521579',
#  'Missing',
#  'Missing',
#  'Missing',
#  'FOON1266647',
#  'D13A2235550',
#  'Missing',
#  'Missing',
#  '013A2899227',
#  'Missing',
#  'Missing',
#  'G4EB9M256677',
#  'D4FA9U817848',
#  'Missing']

# %% [markdown]
# # chasis number

# %%
chasis_list
# Out:
# ['',
#  '',
#  'CHNO MA3ETDE1S00218363\nENO 7567094\n\nMFR MARUTI SUZUKI INDIA LTD\nVEH CL Motor Car',
#  'ae. BEOTAONS OSNO ;\n\nCH. NO MA3FLEB1S00309631 MFG CD\n\nENO Diza2ssae00 owes\nCLASS\n\nMAN (RET emarnee\n\nor\nM\nst\nu',
#  'RES. DE. TU LUTS MFC\nCH. NO : MA3EJKD1S00336606 Cot\nENO : K12MN1262637 CLA\n\nNAME - MR. ANIK NARULA',
#  'RES. UI. vow\nCH. NO : = MA3FDEB1£00381622 COL\nENO ~ D13A1833010 ciA',
#  'She Psp {\nSH. NO | MA3FHEB1S00593004 ;\n\nNO : D13A- 2307158\n: RAKESH KUMAR\n\neee',
#  '',
#  'Vwi Ivy\nMA3EHKD1 S00A97129\n1774707\n\n. Motor Car\nMARIITI C117 LiCl MIA |',
#  'MA3FHEB1 S009¢1906\n597151\nMARUTI SUZUKI INDIA LTD',
#  '4.UT 2411112014\n.NO MA3ETDE1 S00159552\niO K10BN7417497\n\nO SN\nMFG (\nCOLO\nCLAS:',
#  'ae. Se. 8\n\nSew\nCH. NO : MA3FJEB1S00528720\nENO : 0132368228\n\noozxc\n\nen ane el',
#  '',
#  'mi\n\nz*|\n\na evr eareay oa\n\n: MA3EUAG1S00170565\n: FeDN4958005',
#  'CH.NO MA3EWDE1S00637165\nENO K10BN4590508',
#  "'",
# ...

# %%
chasis=[]
for x in range(len(chasis_list)):
    #a=engine_list[x].replace('\n',"")
    chasis.append(chasis_list[x].replace('ENO',""))

chasis_2=[]
for x in range(len(chasis_list)):
    #a=engine_list[x].replace('\n',"")
    chasis_2.append(chasis[x].replace('Chasis No.',""))

pattern=r'[^\W+]+'    

chasis_3=[]
for x in range(len(chasis_list)):
    #a=engine_list[x].replace('\n',"")
    chasis_3.append(re.findall(pattern,chasis_2[x]))

# %%
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
for x in range(len(chasis_3)):
    for y in range(len(chasis_3[x])):
        if len(chasis_3[x][y])<15:
            del chasis_3[x][y]
            break
            
            
            
chasis_3
# Out:
# [[],
#  [],
#  ['MA3ETDE1S00218363'],
#  ['MA3FLEB1S00309631'],
#  ['MA3EJKD1S00336606'],
#  [],
#  ['MA3FHEB1S00593004'],
#  [],
#  [],
#  [],
#  [],
#  ['MA3FJEB1S00528720'],
#  [],
#  ['MA3EUAG1S00170565'],
#  ['MA3EWDE1S00637165'],
#  [],
#  [],
#  ['MA3EFJC1S0151460'],
#  [],
#  [],
#  ['MA3FHEB1S00520199'],
#  [],
#  ['607146KRZW00622'],
#  [],
#  [],
#  [],
#  ['MA3EEJ91S00127444'],
#  [],
#  ['MA3FKEB2S00121766'],
#  ['MA3EYD81S00765439'],
#  ['MASEYD81S01277497'],
#  ['MA3FJEB1S00404062'],
#  [],
#  ['MAZEJKD1S00685213'],
#  [],
#  ['MA3EED81S00628175'],
#  [],
#  ['MALCM41VR9M079263'],
#  ['MA3FHEB1S00356580']]

# %%
for x in range(len(chasis_3)):
    if len(chasis_3[x])>1:
        del chasis_3[x][1]

for x in range(len(chasis_3)):
    if len(chasis_3[x])==0:
        chasis_3[x]=['Missing']

chasis=[]
for x in range(len(chasis_3)):
    chasis.append(chasis_3[x][0]) 

chasis
# Out:
# ['Missing',
#  'Missing',
#  'MA3ETDE1S00218363',
#  'MA3FLEB1S00309631',
#  'MA3EJKD1S00336606',
#  'Missing',
#  'MA3FHEB1S00593004',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'MA3FJEB1S00528720',
#  'Missing',
#  'MA3EUAG1S00170565',
#  'MA3EWDE1S00637165',
#  'Missing',
#  'Missing',
#  'MA3EFJC1S0151460',
#  'Missing',
#  'Missing',
#  'MA3FHEB1S00520199',
#  'Missing',
#  '607146KRZW00622',
#  'Missing',
#  'Missing',
#  'Missing',
#  'MA3EEJ91S00127444',
#  'Missing',
#  'MA3FKEB2S00121766',
#  'MA3EYD81S00765439',
#  'MASEYD81S01277497',
#  'MA3FJEB1S00404062',
#  'Missing',
#  'MAZEJKD1S00685213',
#  'Missing',
#  'MA3EED81S00628175',
#  'Missing',
#  'MALCM41VR9M079263',
#  'MA3FHEB1S00356580']

# %% [markdown]
# # registration date

# %%
registration_date_list
# Out:
# ['',
#  '',
#  'TNE Te\nREGN OT 21/07/2015\nQSNO OF',
#  'ROGOWN. WN\n02/08/2015\n\nMA3FLEB1 $0030\nmaancnnanen',
#  'Ei DT: 18/05/2013\n/H.NO : MA3EJKD1SO',
#  'REG. DT: 03/08/2012\n‘DEB1200381',
#  '',
#  '',
#  'KOON\n\nEGN DT 07/05/2016\n)SNO o1',
#  '"Nev\nEGN OT 13/09/2015\n‘SNO 01',
#  'PN MSIN. IN\nREG DT 2411112014\nCH NO MA3ETDE1S001:',
#  'REG DT 17/05/2014\nCH.NO MA3FJEB1S005287',
#  '',
#  'REG. DT: 14/02/2013\nCH NO: MA3EUAGi SOO',
#  'REG DT 30/11/2013\n\nCH NO MASEWDESO063',
#  'REG. DT: 12/04/2013\n\nCM AO / MASAO. cr',
#  'REG OF\n\n307020"',
#  'REG 07 26/09/2009\nCH NO MA3EFJCiS01¢',
#  '',
#  '',
#  'REG. DT: 06/10/2013\nCH. NO : MA3FHEB1S0052¢',
#  'REG. .. DT: TNIQ2010 ©',
#  'REG. DT: 2\n\nFras BBR / LR WTA ARENA!',
#  'as lc; ls hl] re P A 2 FAS OT BO',
#  '',
#  '',
#  '',
#  'O48 31/01/2005\nMA3EBE41S00',
#  '—— ="\n\nValid From23/01@00e alia',
#  'Fuel Used DIE\nValid From3/11/2013 Val',
#  'Fant ieee) (eS\nVales 1 10080 Bonny HOY Cel',
# ...

# %%
for x in range(len(registration_date_list)):
    registration_date_list[x]=registration_date_list[x].replace('Jan','{:02}'.format(1))
    registration_date_list[x]=registration_date_list[x].replace('Feb','{:02}'.format(2))
    registration_date_list[x]=registration_date_list[x].replace('Mar','{:02}'.format(3))
    registration_date_list[x]=registration_date_list[x].replace('Apr','{:02}'.format(4))
    registration_date_list[x]=registration_date_list[x].replace('May','{:02}'.format(5))
    registration_date_list[x]=registration_date_list[x].replace('Jun','{:02}'.format(6))
    registration_date_list[x]=registration_date_list[x].replace('Jul','{:02}'.format(7))
    registration_date_list[x]=registration_date_list[x].replace('Aug','{:02}'.format(8))
    registration_date_list[x]=registration_date_list[x].replace('Sep','{:02}'.format(9))
    registration_date_list[x]=registration_date_list[x].replace('Oct','{:02}'.format(10))
    registration_date_list[x]=registration_date_list[x].replace('Nov','{:02}'.format(11))
    registration_date_list[x]=registration_date_list[x].replace('Dec','{:02}'.format(12))
    registration_date_list[x]=registration_date_list[x].replace('-','/')

pattern=r'\d{2}/\d{2}/\d{4}'

dates=[]
for x in range(len(registration_date_list)):
    dates.append(re.findall(pattern,registration_date_list[x]))
    
for x in range(len(dates)):
    if len(dates[x])==0:
        dates[x]=['Missing']
        
registration_date=[]
for x in range(len(dates)):
    registration_date.append(dates[x][0])
    
registration_date
# Out:
# ['Missing',
#  'Missing',
#  '21/07/2015',
#  'Missing',
#  '18/05/2013',
#  '03/08/2012',
#  'Missing',
#  'Missing',
#  '07/05/2016',
#  '13/09/2015',
#  'Missing',
#  '17/05/2014',
#  'Missing',
#  '14/02/2013',
#  '30/11/2013',
#  '12/04/2013',
#  'Missing',
#  '26/09/2009',
#  'Missing',
#  'Missing',
#  '06/10/2013',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  '31/01/2005',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing']

# %% [markdown]
# # Manufacturing dates

# %%
mfg_list
# Out:
# ['MEG DT alka\nMFG.OT. —: tamaoie\nPUL bese,',
#  'si',
#  '2 0712015',
#  '',
#  '',
#  'aceaemaae',
#  '',
#  'ee ee ania oan\nMFG OT 2 05/2016 UN\nwee o-',
#  '',
#  'MC',
#  'a:\n\nMFG. DT.\n\n: 04/2014',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Se Se te\n\nome\nIFG.DT. : 09/2013\n: omecec:',
#  'MFG.DT.\n\n- ww\n> 08/2010',
#  'az =, oo ae w=',
#  'WHEEL BASE\nMFG.DT.\n\n: 40',
#  '',
#  '',
#  '',
#  '— : 01/2005\n.». RacTrTom',
#  'f Mig. 11/2008',
#  'g. 912013',
#  'My. 112088',
#  'fg. 5/2016',
#  '> ee\n\nth/ Year of Manufacture 23/01/2008\nre oe eee ee 2 (including dr',
#  '=~ 64 vwe\n\nonth/ Yr of 3 31/12/2009\n\nhana wlaack',
#  ': 1272012\n3, 12/2012\n\n \n\nAn ¢']

# %%
pattern=r'\d{2}/\d{4}'
pattern2=r'\d{2}/\d{2}/\d{4}'

# %%
list_1=[]
list_2=[]
for x in range (len(mfg_list)):
    list_1.append(re.findall(pattern,mfg_list[x]))
    list_2.append(re.findall(pattern2,mfg_list[x]))
for x in range(len(list_2)):
    if len(list_2[x])==0:
        list_2[x]=list_1[x]
for x in range(len(list_2)):
    if len(list_2[x])==0:
        list_2[x]=['Missing']
manufacturing_dates=[]
for x in range(len(list_2)):
    manufacturing_dates.append(list_2[x][0])

# %%
manufacturing_dates
# Out:
# ['Missing',
#  'Missing',
#  '07/2015',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  '10/2014',
#  '04/2014',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  '08/2010',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  'Missing',
#  '23/01/2008',
#  '31/12/2009',
#  'Missing']

# %%
rc_data=pd.DataFrame([name,engine,chasis,registration_date,manufacturing_dates,reg_num]).T
rc_data.columns=['Name','Engine Number','Chasis Number','Registration Date','Manufacturing Date','Registration Number']
rc_data=rc_data.replace('Missing',np.nan)
rc_data=rc_data.replace(0,np.nan)

# %%
rc_data
# Out:
#                  Name       Engine Number      Chasis Number  \
# 0       SRISHTI NAYAR                 NaN                NaN
# 1                 NaN                 NaN                NaN
# 2        ANOOP SURESH                 NaN  MA3ETDE1S00218363
# 3       MANJEET SINGH                 NaN  MA3FLEB1S00309631
# 4         ANIK NARULA        K12MN1262837  MA3EJKD1S00336606
# 5                 NaN         p43A1833010                NaN
# 6        RAKESH KUMAR                 NaN  MA3FHEB1S00593004
# 7                 NaN        K10BN4298995                NaN
# 8        SACHIN KUMAR                 NaN                NaN
# 9             KARAN K   MA3ETDE1S00159552                NaN
# 10     CHANDRA BHUWAN         013A2368228                NaN
# 11                NaN                 NaN  MA3FJEB1S00528720
# 12                NaN                 NaN                NaN
# 13         MAMTA GOEL                 NaN  MA3EUAG1S00170565
# ...

# %%
rc_data.to_excel('Machine Learning Submission- Utkarsh Bhandari.xlsx')
